# %%
import os, sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

from src.preprocessing.preprocess import MovieLensPreprocessor

train_data, val_data, test_data, metadata = MovieLensPreprocessor().process_all()
# Out:
# Loading MovieLens 1M from MinIO bucket 'raw-data'...
#   Users: 5,895  Movies: 3,720  Ratings: 1,000,000
#
# [Feature engineering]
#   Age groups: {np.int64(1): 0, np.int64(18): 1, np.int64(25): 2, np.int64(35): 3, np.int64(45): 4, np.int64(50): 5, np.int64(56): 6}
#   Gender encoding: {'F': 0, 'M': 1}
#   Genre vocabulary size: 19 (including padding=0)
#   Time-of-Day distribution:
#     0 Matinee    :  318,799
#     1 Prime Time :  243,451
#     2 Late Night :  437,750
#
# [Building sequences]
# Building user sequences...
#   Built sequences for 5,893 users
#   Total unique items: 3,471
#
# [Splitting]
# Splitting sequences (leave-one-out)...
#   Train: 770,166  Val: 5,893  Test: 5,893
#
# [Saving to Delta Lake → s3://offline-store/delta/]
#   [train] Overwriting Delta table
#   [train] Written 770,166 rows → s3://offline-store/delta/train
#   [val] Overwriting Delta table
#   [val] Written   5,893 rows → s3://offline-store/delta/val
#   [test] Overwriting Delta table
# ...
