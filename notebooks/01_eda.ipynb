# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Use this notebook to explore raw data from MinIO and inspect features from the Feast offline store.

# %%
import pandas as pd
from deltalake import DeltaTable

STORAGE_OPTIONS = {
    "endpoint_url": "http://localhost:9000",
    "aws_access_key_id": "minioadmin",
    "aws_secret_access_key": "minioadmin123",
}

dt = DeltaTable("s3://offline-store/delta/raw_events", storage_options=STORAGE_OPTIONS)
df = dt.to_pandas()
df.head()
